# %%
import os
from pathlib import Path
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# False

# %%
NOTEBOOK_DIR = Path(os.getcwd())
print("Notebook location  :", NOTEBOOK_DIR)

BASE_DIR = NOTEBOOK_DIR.parent
print("Project base dir  :", BASE_DIR)
# Out:
# Notebook location  : d:\Retail_analytics
# Project base dir  : d:\

# %%
BASE_DIR = Path(os.getcwd()).parent
BASE_DIR
# Out:
# WindowsPath('d:/')

# %%
DATA_DIR = BASE_DIR / "data"
DATA_DIR
# Out:
# WindowsPath('d:/data')

# %%
import os
from pathlib import Path

BASE_DIR =  Path(os.getcwd())
# Out:
# WindowsPath('d:/Retail_analytics')

# %%
DATA_DIR = BASE_DIR / "data"
RAW_DATA_DIR = DATA_DIR / "raw"
PROCESSED_DATA_DIR = DATA_DIR / "processed"
WAREHOUSE_DIR      = DATA_DIR / "warehouse"
DATABASE_DIR       = BASE_DIR / "database"
DATABASE_PATH      = DATABASE_DIR / "retail.db"

paths = {
    "BASE_DIR"          : BASE_DIR,
    "DATA_DIR"          : DATA_DIR,
    "RAW_DATA_DIR"      : RAW_DATA_DIR,
    "PROCESSED_DATA_DIR": PROCESSED_DATA_DIR,
    "WAREHOUSE_DIR"     : WAREHOUSE_DIR,
    "DATABASE_PATH"     : DATABASE_PATH,
}

# %%
for name, path in paths.items():
    exists = "Exists" if path.exists() else "Missing"
    print(f"{name:<22}: {exists} : {path}")
# Out:
# BASE_DIR              : Exists : d:\Retail_analytics
# DATA_DIR              : Exists : d:\Retail_analytics\data
# RAW_DATA_DIR          : Exists : d:\Retail_analytics\data\raw
# PROCESSED_DATA_DIR    : Exists : d:\Retail_analytics\data\processed
# WAREHOUSE_DIR         : Exists : d:\Retail_analytics\data\warehouse
# DATABASE_PATH         : Exists : d:\Retail_analytics\database\retail.db

# %%
BASE_DIR
# Out:
# WindowsPath('d:/Retail_analytics')

# %%
import pandas as pd
import numpy as np
from pathlib import Path
from loguru import logger
import sys
import time

# %%
logger.remove()
